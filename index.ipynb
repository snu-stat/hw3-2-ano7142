# %% [markdown]
# #
#
# # 숙제 3
#
# 이름: 김현연
# 학번: 2025-37423
#
# 이 숙제의 상세 분석 결과는 아래 링크에서 확인하실 수 있습니다.
#
# - [분석 리포트 (HTML)](./hw03.html)
# - [주피터 노트북
#   (ipynb)](https://mybinder.org/v2/gh/snu-stat/hw3-2-ano7142/gh-pages?filepath=hw03.ipynb)
